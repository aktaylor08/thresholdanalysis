# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sumerize_vals
import experiment_examine
import glob
import datetime
import csv
# %matplotlib inline

# %%
info_dir = '../test_data/water_sampler/static_info/'
experiment = '../test_data/water_sampler/dynamic/all_info/experiment3_2015-04-30-15-57-33.csv'
info = sumerize_vals.get_info(info_dir)
thresh_df = sumerize_vals.get_df(experiment, info)
df = pd.read_csv(experiment, parse_dates=True, index_col=0)
action, no_actions = experiment_examine.get_marks(experiment)
no_adv_score = pd.read_csv('../test_data/water_sampler/dynamic/all_info/no_advance/experiment3_2015-04-30-15-57-33_no_advance_scores.csv', parse_dates=True, index_col=0)
adv_score = pd.read_csv('../test_data/water_sampler/dynamic/all_info/advance/experiment3_2015-04-30-15-57-33_advance_scores.csv', parse_dates=True, index_col=0)
# Out:
# Loading file ../test_data/water_sampler/dynamic/all_info/experiment3_2015-04-30-15-57-33.csv

# %%
act = []
for k,x in action.iteritems():
    if isinstance(k,int):
        for y in x:
            act.append(y)
noact = []
for k,x in no_actions.iteritems():
    if isinstance(k,int):
        for y in x:
            noact.append(y)
print act
print noact
# Out:
# []
# [Timestamp('2015-04-30 20:59:16.547453'), Timestamp('2015-04-30 20:59:19.467173'), Timestamp('2015-04-30 20:59:18.547358')]

# %%
for i in act:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res
for i in noact:
    idx = no_adv_score.index.asof(i)
    res = no_adv_score.loc[idx, :]
    res.sort()
    print i
    print res
    print '\n\n'
# Out:
# 2015-04-30 20:59:16.547453
# d4a8c703-b0b9-49d4-aae0-d531c47e2d8a                                                            3.054921e-08
# 0c95250a-abf7-48bc-bff8-4b7193913af1                                                            9.673095e-03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0          8.359448e-01
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject_mod.py:41:0    9.033718e-01
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:106:0          9.999900e+03
# cda4139c-d4c9-465c-98fc-362b7be76b96                                                            9.999900e+03
# c14f7034-f59c-4cfa-a75a-0daaa9d23fa9                                                            9.999900e+03
# b852d108-8540-47bc-a120-b2c983c9ca91                                                            9.999900e+03
# a0140b8a-fbef-43d8-ab07-74319a97bc73                                                            9.999900e+03
# 9cb7cb08-f649-43fb-a4b1-bfdc90b21aae                                                            9.999900e+03
# 98045342-fc4e-4b12-904c-5e494c99903d                                                            9.999900e+03
# 92c529e0-e6e0-4184-98df-653497207a03                                                            9.999900e+03
# 7a1f8257-2d04-476f-baa5-aff1df459502                                                            9.999900e+03
# e2b00838-92ed-413f-b83d-1bf9041c9ac7                                                            9.999900e+03
# 5ab665dd-e8d8-4b63-a809-a482824a5cbe                                                            9.999900e+03
# 552d72ea-07f4-47bd-9f91-ac7031bf3618                                                            9.999900e+03
# 4a595395-30e4-4a1e-ba74-e16c604f7e49                                                            9.999900e+03
# 29e15808-dbdd-45be-81e8-3cabdc8854c6                                                            9.999900e+03
# 26d9dac7-4db1-4c40-9b23-d726e4e8ee90                                                            9.999900e+03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:55:
home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:55:0           9.999900e+03
# 87f42589-e261-4133-a05d-89a706217982                                                            9.999900e+03
# e37b2e60-f59e-46f4-9ade-37684865cd29                                                            9.999900e+03
# Name: 2015-04-30 20:59:18.471749, dtype: float64

# %%
print info['d4a8c703-b0b9-49d4-aae0-d531c47e2d8a']
print info['0c95250a-abf7-48bc-bff8-4b7193913af1']
# Out:
# {u'publishes': 1, u'distance': 2, u'file': u'/home/ataylor/water_sampler_experiment/src/mit_asctec/supervision/src/asctec_monitor_thread.cpp', u'name': u'waypose_idle_timeout in /home/ataylor/water_sampler_experiment/src/mit_asctec/supervision/src/asctec_monitor_thread.cpp', u'source': u'waypose_idle_timeout', u'param_reads': 2, u'topic': u'unknown', u'other_thresholds': 0, u'relation': u'', u'lineno': 53, u'key': u'd4a8c703-b0b9-49d4-aae0-d531c47e2d8a', u'source_code': u'', u'type': u'Parameter'}
# {u'publishes': 8, u'distance': 5, u'file': u'/home/ataylor/water_sampler_experiment/src/mit_asctec/protocol/src/asctec_prot_parse.cpp', u'name': u'max_pkt_size in /home/ataylor/water_sampler_experiment/src/mit_asctec/protocol/src/asctec_prot_parse.cpp', u'source': u'max_pkt_size', u'param_reads': 5, u'topic': u'unknown', u'other_thresholds': 0, u'relation': u'', u'lineno': 49, u'key': u'0c95250a-abf7-48bc-bff8-4b7193913af1', u'source_code': u'', u'type': u'Parameter'}

# %%
fig, axes = plt.subplots(2, 1, sharex=True)
ax = axes[0]
df.a_subject_pose__translation_z.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax )
lims = ax.get_ylim()
pairs = [(x,(lims[0] + lims[1]) /2) for x in act]
nopairs = [(x,(lims[0] + lims[1]) /2) for x in noact]
#print zip(*pairs)
#ax.scatter(zip(*pairs)[0], zip(*pairs)[1], c='r',marker='x', s=200)
ax.scatter(zip(*nopairs)[0], zip(*nopairs)[1], c='g', marker='x', s=200)
ax.set_ylabel('Height (m)', fontsize=20)
ax.set_xlabel('Time', fontsize=20)

ax = axes[1]
df.a_subject_pose__translation_x.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax)
#df.a_subject_pose__translation_y.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax )

lims = ax.get_ylim()
pairs = [(x,(lims[0] + lims[1]) /2) for x in act]
nopairs = [(x,(lims[0] + lims[1]) /2) for x in noact]
#print zip(*pairs)
#ax.scatter(zip(*pairs)[0], zip(*pairs)[1], c='r',marker='x', s=200)
ax.scatter(zip(*nopairs)[0], zip(*nopairs)[1], c='g', marker='x', s=200)
ax.set_ylabel('X Location (m)', fontsize=20)
ax.set_xlabel('Time', fontsize=20)



fig.savefig('../../thesis/myFigures/waterMission3.png')

# %%
vals = df[df.a_subject_pose__translation_x < -2]

# %%
at_loc = vals.index[0]

# %%
print noact[0] - at_loc
print noact[1] - at_loc
print noact[2] - at_loc
# Out:
# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-dcf9a754ae1d> in <module>()
#       1 for i in noact:
# ----> 2    print i - idx
#       3 for i in act:
#       4     print i -idx
#
# TypeError: unsupported operand type(s) for -: 'Timestamp' and 'str'

# %%
for i in act:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res[0], res.index[0]

# %%
for i in noact:
    idx = no_adv_score.index.asof(i)
    res = no_adv_score.loc[idx, :]
    res.sort()
    for idx, val in res.iteritems():
        if val < 9999.9:
            print res[idx], idx
            print info[idx]['source']
# Out:
# 3.29960221752e-08 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 0.00962077171339 0c95250a-abf7-48bc-bff8-4b7193913af1
# max_pkt_size
# 0.840104368807 /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0
# altitude_abort_level
# 0.929860219611 /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject_mod.py:41:0
# xy_error_allowed
# 3.5093293625e-08 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 0.00965390733188 0c95250a-abf7-48bc-bff8-4b7193913af1
# max_pkt_size
# 0.838281689473 /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0
# altitude_abort_level
# 0.913845796887 /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject_mod.py:41:0
# xy_error_allowed
# 3.43942031417e-08 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 0.00961000873789 0c95250a-abf7-48bc-bff8-4b7193913af1
# max_pkt_size
# 0.842275559779 /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0
# altitude_abort_level
# 0.91975314034 /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject_mod.py:41:0
# xy_error_allowed

# %%
no_adv_score[no_adv_score[key] != 9999.9][key].plot()

# %%
for i in noact:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res[0], res.index[0]
    print info[res.index[0]]['source']
# Out:
# 49.436071 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 52.336071 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 51.436071 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout

# %%
ax = no_adv_score.min(axis=1).plot(figsize=(11 ,8.5), linewidth=3)
ax.scatter(no_adv_score[key].index, no_adv_score[key], marker='x', c='r')
ax.set_ylim(0,2)
# Out:
# (0, 2)

# %%
no_max = no_adv_score.min(axis=1) < 9999
no_oob = no_adv_score[no_max]

# %%
a = no_oob.idxmin(axis=1).value_counts() / len(no_oob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e69b43f81de5> in <module>()
# ----> 1 a = no_oob.idxmin(axis=1).value_counts() / len(no_oob)
#
# NameError: name 'no_oob' is not defined

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
times = {}
last = None
st = None
for t, v in no_oob.idxmin(axis=1).iteritems():
    if last is None:
        last = v
        st = t
    elif last != v:
        telapsed = t - st
        dt = (telapsed).total_seconds()
        st = t
        last = v
        if last in times:
            times[last].append(dt)
        else:
            times[last] = [dt]

# %%
print times
vals = []
for i, dom_times in times.iteritems():
    print info[i]['source'], np.mean(dom_times)
    vals.append(np.mean(dom_times))
# Out:
# {'d4a8c703-b0b9-49d4-aae0-d531c47e2d8a': [0.9, 9.0, 8.0], '0c95250a-abf7-48bc-bff8-4b7193913af1': [42.0, 36.0]}
# waypose_idle_timeout 5.96666666667
# max_pkt_size 39.0

# %%
np.mean(vals)
# Out:
# 22.483333333333334

# %%
no_adv_score[key]
# Out:
# 2015-04-30 20:57:43.171749    9999.900000
# 2015-04-30 20:57:43.271749    9999.900000
# 2015-04-30 20:57:43.371749    9999.900000
# 2015-04-30 20:57:43.471749    9999.900000
# 2015-04-30 20:57:43.571749    9999.900000
# 2015-04-30 20:57:43.671749    9999.900000
# 2015-04-30 20:57:43.771749    9999.900000
# 2015-04-30 20:57:43.871749    9999.900000
# 2015-04-30 20:57:43.971749    9999.900000
