# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sumerize_vals
import experiment_examine
import glob
import datetime
import csv
# %matplotlib inline

# %%
info_dir = '../test_data/water_sampler/static_info/'
experiment = '../test_data/water_sampler/dynamic/all_info/experiment2_2015-04-30-15-54-45.csv'
info = sumerize_vals.get_info(info_dir)
thresh_df = sumerize_vals.get_df(experiment, info)
df = pd.read_csv(experiment, parse_dates=True, index_col=0)
action, no_actions = experiment_examine.get_marks(experiment)
no_adv_score = pd.read_csv('../test_data/water_sampler/dynamic/all_info/no_advance/experiment2_2015-04-30-15-54-45_no_advance_scores.csv', parse_dates=True, index_col=0)
adv_score = pd.read_csv('../test_data/water_sampler/dynamic/all_info/advance/experiment2_2015-04-30-15-54-45_advance_scores.csv', parse_dates=True, index_col=0)
# Out:
# Loading file ../test_data/water_sampler/dynamic/all_info/experiment2_2015-04-30-15-54-45.csv

# %%
act = []
for k,x in action.iteritems():
    if isinstance(k,int):
        for y in x:
            act.append(y)
noact = []
for k,x in no_actions.iteritems():
    if isinstance(k,int):
        for y in x:
            noact.append(y)
print act
print noact
# Out:
# []
# [Timestamp('2015-04-30 20:55:58.788909')]

# %%
for i in act:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res
for i in noact:
    idx = no_adv_score.index.asof(i)
    res = no_adv_score.loc[idx, :]
    res.sort()
    print res
# Out:
# d4a8c703-b0b9-49d4-aae0-d531c47e2d8a                                                                        1.197640e-08
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject.py:41:0                    7.149407e-03
# 0c95250a-abf7-48bc-bff8-4b7193913af1                                                                        9.136799e-03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0                      9.562361e-01
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:106:0                      9.999900e+03
# cda4139c-d4c9-465c-98fc-362b7be76b96                                                                        9.999900e+03
# c14f7034-f59c-4cfa-a75a-0daaa9d23fa9                                                                        9.999900e+03
# b852d108-8540-47bc-a120-b2c983c9ca91                                                                        9.999900e+03
# a0140b8a-fbef-43d8-ab07-74319a97bc73                                                                        9.999900e+03
# 9cb7cb08-f649-43fb-a4b1-bfdc90b21aae                                                                        9.999900e+03
# 98045342-fc4e-4b12-904c-5e494c99903d                                                                        9.999900e+03
# 92c529e0-e6e0-4184-98df-653497207a03                                                                        9.999900e+03
# 7a1f8257-2d04-476f-baa5-aff1df459502                                                                        9.999900e+03
# e2b00838-92ed-413f-b83d-1bf9041c9ac7                                                                        9.999900e+03
# 5ab665dd-e8d8-4b63-a809-a482824a5cbe                                                                        9.999900e+03
# 552d72ea-07f4-47bd-9f91-ac7031bf3618                                                                        9.999900e+03
# 4a595395-30e4-4a1e-ba74-e16c604f7e49                                                                        9.999900e+03
# 29e15808-dbdd-45be-81e8-3cabdc8854c6                                                                        9.999900e+03
# 26d9dac7-4db1-4c40-9b23-d726e4e8ee90                                                                        9.999900e+03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:157:0    9.999900e+03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:55:0                       9.999900e+03
# 87f42589-e261-4133-a05d-89a706217982                                                                        9.999900e+03
# e37b2e60-f59e-46f4-9ade-37684865cd29                                                                        9.999900e+03
# Name: 2015-04-30 20:55:58.771469, dtype: float64

# %%
fig, axes = plt.subplots(2, 1, sharex=True)
ax = axes[0]
df.a_subject_pose__translation_z.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax )
lims = ax.get_ylim()
pairs = [(x,(lims[0] + lims[1]) /2) for x in act]
nopairs = [(x,(lims[0] + lims[1]) /2) for x in noact]
#print zip(*pairs)
#ax.scatter(zip(*pairs)[0], zip(*pairs)[1], c='r',marker='x', s=200)
ax.scatter(zip(*nopairs)[0], zip(*nopairs)[1], c='g', marker='x', s=200)
ax.set_ylabel('Height (m)', fontsize=20)
ax.set_xlabel('Time', fontsize=20)

ax = axes[1]
df.a_subject_pose__translation_x.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax)
#df.a_subject_pose__translation_y.dropna().plot(figsize=(11,8.5), fontsize=20,linewidth=4, ax=ax )

lims = ax.get_ylim()
pairs = [(x,(lims[0] + lims[1]) /2) for x in act]
nopairs = [(x,(lims[0] + lims[1]) /2) for x in noact]
#print zip(*pairs)
print nopairs
#ax.scatter(zip(*pairs)[0], zip(*pairs)[1], c='r',marker='x', s=200)
ax.scatter(zip(*nopairs)[0], zip(*nopairs)[1], c='g', marker='x', s=200)
ax.set_ylabel('X Location (m)', fontsize=20)
ax.set_xlabel('Time', fontsize=20)



fig.savefig('../../thesis/myFigures/waterMission2.png')
# Out:
# [(Timestamp('2015-04-30 20:55:58.788909'), -1.25)]

# %%
vals = df[df.a_subject_pose__translation_x < -2]

# %%
at_loc = vals.index[0]

# %%
 noact[0] - at_loc
# Out:
# Timedelta('0 days 00:00:21.055517')

# %%
thresh_df.key.unique()
# Out:
# array(['0c95250a-abf7-48bc-bff8-4b7193913af1',
#        '92c529e0-e6e0-4184-98df-653497207a03',
#        '5ab665dd-e8d8-4b63-a809-a482824a5cbe',
#        'e37b2e60-f59e-46f4-9ade-37684865cd29',
#        'd4a8c703-b0b9-49d4-aae0-d531c47e2d8a',
#        '/home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:55:0',
#        '/home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:106:0',
#        'c14f7034-f59c-4cfa-a75a-0daaa9d23fa9',
#        '26d9dac7-4db1-4c40-9b23-d726e4e8ee90',
#        'b852d108-8540-47bc-a120-b2c983c9ca91',
#        'a0140b8a-fbef-43d8-ab07-74319a97bc73',
#        '29e15808-dbdd-45be-81e8-3cabdc8854c6',
#        'cda4139c-d4c9-465c-98fc-362b7be76b96',
#        '7a1f8257-2d04-476f-baa5-aff1df459502',
#        '87f42589-e261-4133-a05d-89a706217982',
#        '98045342-fc4e-4b12-904c-5e494c99903d',
#        '552d72ea-07f4-47bd-9f91-ac7031bf3618',
#        '4a595395-30e4-4a1e-ba74-e16c604f7e49',
#        '9cb7cb08-f649-43fb-a4b1-bfdc90b21aae',
#        '/home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0',
#        'e2b00838-92ed-413f-b83d-1bf9041c9ac7',
#        '/home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject.py:41:0',
#        '/home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:157:0'], dtype=object)

# %%
key = '/home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToOb
# 2015-04-30 20:55:35.180631       1  True    1.00   True            None
# 2015-04-30 20:55:47.257330999    1  True    0.03   True            None
# 2015-04-30 20:55:50.180627       0  True    1.00  False            None
# 2015-04-30 20:55:51.180631       1  True    1.00   True            None
# 2015-04-30 20:55:54.283591       0  True  256.00  False            None
# 2015-04-30 20:55:54.399594       1  True  256.00   True            None
# 2015-04-30 20:55:55.180636       0  True    1.00  False            None
# 2015-04-30 20:55:56.180737       1  True    1.00   True            None
# 2015-04-30 20:55:59.180624       0  True    1.00  False            None
# 2015-04-30 20:56:00.180639       1  True    1.00   True            None
# 2015-04-30 20:56:06.532939999    0  True  256.00  False            None
# 2015-04-30 20:56:06.620952       1  True  256.00   True            None
# 2015-04-30 20:56:10.180623       0  True    1.00  False            None
# 2015-04-30 20:56:11.180628       1  True    1.00   True            None
# 2015-04-30 20:56:14.007248       1  True    0.20   True            None
# 2015-04-30 20:56:15.892617       0  True    0.20  False            None
# 2015-04-30 20:56:18.181329       0  True    1.00  False            None
#
#                                         cmp
# 2015-04-30 20:55:26.180631         0.032543
# 2015-04-30 20:55:28.180625         1.232540
# 2015-04-30 20:55:28.580643         0.321661
# 2015-04-30 20:55:31.096654         0.199315
# 2015-04-30 20:55:31.717018         0.099793
# 2015-04-30 20:55:31.806640         1.094840
# 2015-04-30 20:55:32.946841         0.098387
# 2015-04-30 20:55:34.180634         0.174066
# 2015-04-30 20:55:35.180631         1.174070
# 2015-04-30 20:55:47.257330999      0.024941
# 2015-04-30 20:55:50.180627         0.173562
# 2015-04-30 20:55:51.180631         1.173560
# 2015-04-30 20:55:54.283591     50431.000000
# 2015-04-30 20:55:54.399594        92.000000
# 2015-04-30 20:55:55.180636         0.173514
# 2015-04-30 20:55:56.180737         1.173620
# 2015-04-30 20:55:59.180624         0.898574
# 2015-04-30 20:56:00.180639         1.898580
# 2015-04-30 20:56:06.532939999  21852.000000
# 2015-04-30 20:56:06.620952        16.000000
# 2015-04-30 20:56:10.180623         0.173761
# 2015-04-30 20:56:11.180628         1.173760
# 2015-04-30 20:56:14.007248         1.024260
# 2015-04-30 20:56:15.892617         0.198053
# 2015-04-30 20:56:18.181329         0.074367

# %%
idx = ft.index[0]
info['0c95250a-abf7-48bc-bff8-4b7193913af1']
# Out:
# {u'distance': 5,
#  u'file': u'/home/ataylor/water_sampler_experiment/src/mit_asctec/protocol/src/asctec_prot_parse.cpp',
#  u'key': u'0c95250a-abf7-48bc-bff8-4b7193913af1',
#  u'lineno': 49,
#  u'name': u'max_pkt_size in /home/ataylor/water_sampler_experiment/src/mit_asctec/protocol/src/asctec_prot_parse.cpp',
#  u'other_thresholds': 0,
#  u'param_reads': 5,
#  u'publishes': 8,
#  u'relation': u'',
#  u'source': u'max_pkt_size',
#  u'source_code': u'',
#  u'topic': u'unknown',
#  u'type': u'Parameter'}

# %%
for i in noact:
   print i - idx
for i in act:
    print i -idx
# Out:
# 0 days 00:00:11.531578

# %%
for i in noact:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res[0], res.index[0]
# Out:
# 8.45163025269 0c95250a-abf7-48bc-bff8-4b7193913af1

# %%
for i in noact:

    idx = no_adv_score.index.asof(i)
    res = no_adv_score.loc[idx, :]
    res.sort()
    for idx, val in res.iteritems():
        if val < 9999.9:
            print res[idx], idx
            print info[idx]['source']
# Out:
# 1.19763996374e-08 d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# waypose_idle_timeout
# 0.00714940736369 /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject.py:41:0
# xy_error_allowed
# 0.00913679885475 0c95250a-abf7-48bc-bff8-4b7193913af1
# max_pkt_size
# 0.956236097219 /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0
# altitude_abort_level

# %%
no_adv_score[adv_score[key] != 9999.9][key].plot()

# %%
for i in noact:
    idx = adv_score.index.asof(i)
    res = adv_score.loc[idx, :]
    res.sort()
    print res[0], res.index[0]
    print info[res.index[0]]['source']
# Out:
# 8.45163025269 0c95250a-abf7-48bc-bff8-4b7193913af1
# max_pkt_size

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11,8.5)
ax.scatter(no_adv_score[key].index, no_adv_score[key], marker='x', c='r')
xlims = ax.get_xlim()
no_adv_score.min(axis=1).plot(figsize=(11 ,8.5), linewidth=3, ax=ax)
ax.set_ylim(0,2)
# Out:
# (0, 2)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11,8)
for i in no_adv_score.columns:
    data = no_adv_score[no_adv_score[i] != 9999.9]
    if len(data) > 1:
        data[i].plot()

# %%
no_max = no_adv_score.min(axis=1) < 9999
no_oob = no_adv_score[no_max]

# %%
a = no_oob.idxmin(axis=1).value_counts() / len(no_oob)

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
times = {}
last = None
st = None
for t, v in no_oob.idxmin(axis=1).iteritems():
    if last is None:
        last = v
        st = t
    elif last != v:
        telapsed = t - st
        dt = (telapsed).total_seconds()
        st = t
        last = v
        if last in times:
            times[last].append(dt)
        else:
            times[last] = [dt]

# %%
print times
vals = []
for i, dom_times in times.iteritems():
    print info[i]['source'], np.mean(dom_times)
    vals.append(np.mean(dom_times))
# Out:
# {'d4a8c703-b0b9-49d4-aae0-d531c47e2d8a': [0.9, 16.0], '0c95250a-abf7-48bc-bff8-4b7193913af1': [42.0, 29.0]}
# waypose_idle_timeout 8.45
# max_pkt_size 35.5

# %%
np.mean(vals)
# Out:
# 21.975000000000001

# %%
for i in thresh_df
# Out:
#   File "<ipython-input-209-6933d08e3e39>", line 1
#     for i in thresh_df
#                       ^
# SyntaxError: invalid syntax

# %%
a = thresh_df[thresh_df.key == 'd4a8c703-b0b9-49d4-aae0-d531c47e2d8a']

# %%
a.cmp.plot()
print info['d4a8c703-b0b9-49d4-aae0-d531c47e2d8a']['file']
print info['d4a8c703-b0b9-49d4-aae0-d531c47e2d8a']['lineno']
print info['d4a8c703-b0b9-49d4-aae0-d531c47e2d8a']['source']

# %%
a.thresh.plot()

# %%
df.a_distance_to_task_pose__dist.dropna().plot()

# %%
df.a_subject_pose__translation_x.dropna().plot()

# %%
for i,d in thresh_df.groupby('key'):
    ax =  d.thresh.plot(linewidth=4)
ax.set_ylim(-1,2)

# %%
for i in info:
    print i
# Out:
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToHeight.py:17:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:162:0
# 721c95c2-164b-4b3d-9fbb-ff8ecba27283
# 98045342-fc4e-4b12-904c-5e494c99903d
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:115:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_best_subject_pose/h2oBestSubjectPose_VICON.py:74:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:118:0
# 7a437241-7633-474d-909f-aaf92d69f726
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:106:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:106:0
# c14f7034-f59c-4cfa-a75a-0daaa9d23fa9
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:150:0
# cda4139c-d4c9-465c-98fc-362b7be76b96
# 4a595395-30e4-4a1e-ba74-e16c604f7e49
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:92:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:55:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_test/DEV/myTester.py:38:1
# a0140b8a-fbef-43d8-ab07-74319a97bc73
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:174:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject.py:41:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_test/DEV/myTester.py:38:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:112:0
# 77685e7d-31ec-4ba5-b51b-c147cf483ee8
# b852d108-8540-47bc-a120-b2c983c9ca91
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:69:0
# 9b856bfa-6d6f-4347-90f8-d44e34e85c2a
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:110:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:82:0
# 5047190e-6a31-4d2d-a683-a0d5fd48cb6f
# 26d9dac7-4db1-4c40-9b23-d726e4e8ee90
# 9444fa56-ef86-462f-b84a-070483b1952c
# /home/ataylor/water_sampler_experiment/src/mit_asctec/script_input/scripts/basic_commands.py:66:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:182:0
# fe80692b-ba58-472a-a93a-2d9bf79a6d74
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:77:0
# e86886f6-99a8-4fa3-813e-f4385f20753f
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:133:0
# a3e7abe5-66e4-436a-88ee-40e0002958cb
# e2b00838-92ed-413f-b83d-1bf9041c9ac7
# 55c549ff-1ea9-43a5-ac2b-e75816a46d8c
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:62:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:168:0
# c1bb931b-b670-46fe-9012-446570b1839c
# a86765b6-40d1-42ae-a202-b1c425ed7b3f
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:142:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToObject_mod.py:41:0
# 7330670a-bd10-4a06-af8e-c391db2861d9
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:261:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_best_subject_pose/h2oBestSubjectPose_VICON.py:75:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:102:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:55:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:146:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:129:1
# 29e15808-dbdd-45be-81e8-3cabdc8854c6
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_best_subject_pose/h2oBestSubjectPose_GPS.py:61:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:78:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:129:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:126:0
# 0c95250a-abf7-48bc-bff8-4b7193913af1
# 5ab665dd-e8d8-4b63-a809-a482824a5cbe
# a8376f0b-65e0-4e7b-9a45-1f326fc0818f
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:317:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_best_subject_pose/h2oBestSubjectPose_VICON.py:64:0
# 87f42589-e261-4133-a05d-89a706217982
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:130:0
# 9cb7cb08-f649-43fb-a4b1-bfdc90b21aae
# 552d72ea-07f4-47bd-9f91-ac7031bf3618
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachineDemo.py:104:0
# f2a042fe-a528-4348-9dce-af23e5b23300
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:93:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:138:0
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_substate_machine/h2oSubstateMachine.py:157:0
# 92c529e0-e6e0-4184-98df-653497207a03
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/script_utils/FlyToHeight.py:67:0
# 879d6838-0b9f-458f-b69b-d83ef7285121
# d4a8c703-b0b9-49d4-aae0-d531c47e2d8a
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_xbox/xbox_water_sampler_spool.py:70:0
# 7a1f8257-2d04-476f-baa5-aff1df459502
# /home/ataylor/water_sampler_experiment/src/h2o_sampling/h2o_safety/h2o_safety.py:119:0
# e37b2e60-f59e-46f4-9ade-37684865cd29
# 36c70bce-7e93-4dd0-a464-288c64783f91

# %%
df.a_distance_to_task_pose__dist.dropna().plot()

# %%
thresh_df[thresh_df['key'] == key].plot()
