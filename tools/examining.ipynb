# %%
import pandas as pd

# %%
df = pd.read_csv('./by_package.csv', index_col=0)

# %%
df
# Out:
#                       name  clean_time  additional_time  \
# 0                turtlebot  178.234325       301.529403
# 1           crop_surveying  132.512369       167.488969
# 2       Asctec Mav Pacakge   61.817786       301.354521
# 3                      NAO  187.594679       234.829294
# 4               next stage    0.000000         0.000000
# 5           robitician ric   28.597711        32.676464
# 6       ros filter library    8.952956        13.111237
# 7              app_manager    8.199352         8.061419
# 8            water_sampler   26.449281        30.059060
# 9                       pr  325.486791       978.901775
# 10          BWI from Texas  241.486559       223.991381
# 11             Rail Robots  141.062656       795.501470
# 12        navigation stack  172.623571       308.859603
# 13           Grizzly robot   25.955180        25.627337
# 14       ROS Create Driver   19.079273        18.909228
# 15           Nav2 platform   19.537903        22.179384
# ...

# %%
df['Total LOC'].mean()
# Out:
# 14768.846153846154

# %%
df['Total LOC'].describe()
# Out:
# count        52.000000
# mean      14768.846154
# std       35895.750861
# min           0.000000
# 25%        1096.750000
# 50%        5089.500000
# 75%       10718.750000
# max      229936.000000
# Name: Total LOC, dtype: float64

# %%
# %matplotlib inline

# %%
df['Total Files'].describe()
# Out:
# count     52.000000
# mean      85.538462
# std      132.038239
# min        0.000000
# 25%       15.000000
# 50%       42.500000
# 75%       92.000000
# max      606.000000
# Name: Total Files, dtype: float64

# %%
df['Total Files'].median()
# Out:
# 42.5

# %%
df['Total Files'].median?
# Out:
# Object `median` not found.

# %%
df['Total Files'].median

# %%
df.files.mean()
# Out:
# 2.7692307692307692

# %%
ot = df[df.threshold_comparisions > 0]

# %%
ot
# Out:
#                     name  clean_time  additional_time  threshold_comparisions  \
# 0              turtlebot  178.234325       301.529403                      46
# 1         crop_surveying  132.512369       167.488969                       3
# 3                    NAO  187.594679       234.829294                      28
# 5         robitician ric   28.597711        32.676464                      16
# 7            app_manager    8.199352         8.061419                       1
# 8          water_sampler   26.449281        30.059060                      30
# 9                     pr  325.486791       978.901775                      42
# 10        BWI from Texas  241.486559       223.991381                       8
# 11           Rail Robots  141.062656       795.501470                       1
# 12      navigation stack  172.623571       308.859603                      46
# 14     ROS Create Driver   19.079273        18.909228                      38
# ...

# %%
ot.files()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-471389c5e1c3> in <module>()
# ----> 1 ot.files()
#
# TypeError: 'Series' object is not callable

# %%
ot.files.mean()
# Out:
# 4.3636363636363633

# %%
ot.unique.mean()
# Out:
# 14.484848484848484
