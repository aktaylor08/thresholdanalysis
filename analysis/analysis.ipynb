# %%
import pandas 
import matplotlib.pyplot as plt
import numpy
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
# %matplotlib inline

# %%
thresh = pandas.read_csv('/Users/ataylor/Downloads/_2015-01-30-16-53-42_thresh.csv', parse_dates=True, index_col=0)
df = pandas.read_csv('/Users/ataylor/Downloads/_2015-01-30-16-53-42.csv', parse_dates=True, index_col=0)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.py:1130: DtypeWarning: Columns (14,15,16,17,18,140,142,156,157,158,182,191,192,194) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
no_actions = df.mark_no_action__data_nsecs.dropna().index

# %%
removed = thresh[thresh['key'] != '/home/ataylor/ros_ws/water/src/h2o_substate_machine/h2oSubstateMachine.py:150']

# %%
 key_groups = removed.groupby('key')

# %%
key_groups[['cmp_0_0', 'const_0_0']].describe()
# Out:
#                                                                                              cmp_0_0  \
# key
# /home/ataylor/ros_ws/water/src/h2o_safety/h2o_safety.py:112                   count             1736
#                                                                               unique              15
#                                                                               top             10.855
#                                                                               freq               850
# /home/ataylor/ros_ws/water/src/h2o_safety/h2o_safety.py:46                    count             1736
#                                                                               unique               1
#                                                                               top              False
#                                                                               freq              1736
# ...

# %%
removed.to_csv('filtered_thresh.csv')
